# %% [markdown]
# <a href="https://colab.research.google.com/github/RodrigoVelazquez1982/ArchivosCoder/blob/main/trabajo-en-clase_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Hacer un primer grafico con Matplotlib y seaborn
# 🔗[Esta es la presentacion](https://docs.google.com/presentation/d/1OhwYkGXfY9xDGjP7cRscmms6Cd4ogESgaRvRY17fY-I/edit#slide=id.g2aa193d3eb5_0_0)

# %%
import pandas
import seaborn as sns
import matplotlib.pyplot as plt

# %%
x:list[str] = ['EDA','Data Wrangling','Mineria datos','Limpieza Datos','SQL','Est. Inferencial','ML','DL','IA']
y:list[int] = [5,10,15,20,30,25,31,30,20]

# %%
data_dict:dict = {
    "caracteristicas":x,
    "Frecuencia" :y
}

data_dict
# Out:
# {'caracteristicas': ['EDA',
#   'Data Wrangling',
#   'Mineria datos',
#   'Limpieza Datos',
#   'SQL',
#   'Est. Inferencial',
#   'ML',
#   'DL',
#   'IA'],
#  'Frecuencia': [5, 10, 15, 20, 30, 25, 31, 30, 20]}

# %%
df = pandas.DataFrame(data_dict) #dataframe

# %%
df
# Out:
#     caracteristicas  Frecuencia
# 0               EDA           5
# 1    Data Wrangling          10
# 2     Mineria datos          15
# 3    Limpieza Datos          20
# 4               SQL          30
# 5  Est. Inferencial          25
# 6                ML          31
# 7                DL          30
# 8                IA          20
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df['Frecuencia'].plot(kind='hist', bins=20, title='Frecuencia')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df['Frecuencia'].plot(kind='line', figsize=(8, 4), title='Frecuencia')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
df['Frecuencia'].plot(kind='hist', bins=20, title='Frecuencia')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
plt.figure(figsize=(16,9))
sns.barplot(df, x="caracteristicas", y="Frecuencia")
plt.bar(x=x, height=y) # barplot
plt.xticks(rotation=45) # Rotamos etiquetas eje x
plt.ylabel('Frecuencia') # Label y
plt.title('Barplot Caracteristicas') # titulo
plt.tight_layout() # ajuste de ejes
plt.grid(axis='y') # grilla
plt.show()
